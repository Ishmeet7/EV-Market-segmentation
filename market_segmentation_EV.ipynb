# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishmeet7/EV-Market-segmentation/blob/main/market_segmentation_EV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
state_data=pd.read_csv("/content/drive/MyDrive/archive/EV_India.csv")
EV_India=pd.read_csv("/content/drive/MyDrive/EVIndia.csv")
India_data=pd.read_csv("/content/drive/MyDrive/EV_India (1).csv")

# %%
state_data.head()
# Out:
#    Sr. No.                State Name Total Electric Vehicle  \
# 0        1  Andaman & Nicobar Island                    162
# 1        2             Andra Pradesh                    NaN
# 2        3         Arunachal Pradesh                     20
# 3        4                     Assam                  64766
# 4        5                     Bihar                  83335
#
#   Total Non-Electric Vehicle        Total
# 0                   1,46,945     1,47,107
# 1                        NaN          NaN
# 2                   2,52,965     2,52,985
# 3                  46,77,053    47,41,819
# 4                1,04,07,078  1,04,90,413

# %%
state_data
# state_data.dropna(inplace=True)
# state_data["Total Electric Vehicle"].astype(int)
# Out:
#     Sr. No.                State Name Total Electric Vehicle  \
# 0         1  Andaman & Nicobar Island                    162
# 2         3         Arunachal Pradesh                     20
# 3         4                     Assam                  64766
# 4         5                     Bihar                  83335
# 5         6                Chandigarh                   2812
# 6         7              Chhattisgarh                  20966
# 7         8                     Delhi               1,56,393
# 8         9                       Goa                   3870
# 9        10                   Gujarat                  45272
# 10       11                   Haryana                  37035
# 11       12          Himachal Pradesh                   1175
# 12       13         Jammu and Kashmir                   2941
# 13       14                 Jharkhand                  16811
# 14       15                 Karnataka               1,20,532
# 15       16                    Kerala                  30775
# 16       17                    Ladakh                     26
# 19       20               Maharashtra               1,16,646
# 20       21                   Manipur                    586
# 21       22                 Meghalaya                     49
# 22       23                   Mizoram                     21
# 23       24                  Nagaland                     58
# 24       25                    Odisha                  23371
# 25       26                Puducherry                   2149
# 26       27                    Punjab                  14804
# 27       28                 Rajasthan                  81338
# 28       29                    Sikkim                     21
# 29       30                Tamil Nadu                  82051
# 31       32                   Tripura                   9262
# 32       33          UT of DNH and DD                    183
# 33       34               Uttarakhand                  31008
# 34       35             Uttar Pradesh               3,37,180
# 35       36               West Bengal                  48767
#
#    Total Non-Electric Vehicle        Total
# 0                    1,46,945     1,47,107
# 2                    2,52,965     2,52,985
# 3                   46,77,053    47,41,819
# 4                 1,04,07,078  1,04,90,413
# 5                    7,46,881     7,49,693
# 6                   68,36,200    68,57,166
# 7                   76,85,600    78,41,993
# 8                   10,71,570    10,75,440
# 9                 2,06,05,484  2,06,50,756
# 10                1,07,78,270  1,08,15,305
# 11                  19,64,754    19,65,929
# 12                  18,69,962    18,72,903
# 13                  64,86,937    65,03,748
# 14                2,68,70,303  2,69,90,835
# 15                1,57,74,078  1,58,04,853
# 16                      38302        38328
# 19                3,10,58,990  3,11,75,636
# 20                   4,99,324     4,99,910
# 21                   4,59,001     4,59,050
# 22                   3,15,626     3,15,647
# 23                   3,39,129     3,39,187
# 24                  98,45,073    98,68,444
# 25                  12,13,735    12,15,884
# 26                1,24,63,019  1,24,77,823
# 27                1,73,27,388  1,74,08,726
# 28                      97189        97210
# 29                2,98,42,376  2,99,24,427
# 31                   6,50,026     6,59,288
# 32                   3,07,671     3,07,854
# 33                  33,12,041    33,43,049
# 34                4,00,92,490  4,04,29,670
# 35                1,41,34,171  1,41,82,938

# %%
state_data.columns
# Out:
# Index(['Sr. No.', 'State Name', 'Total Electric Vehicle',
#        'Total Non-Electric Vehicle', 'Total'],
#       dtype='object')

# %%
sorted_state_data=state_data.sort_values("Total Electric Vehicle")
sorted_state_data=sorted_state_data.dropna()
sorted_state_data.drop('Sr. No.', axis=1, inplace = True)

# %%
sorted_state_data  #top 5 states
# Out:
#                   State Name Total Electric Vehicle  \
# 19               Maharashtra               1,16,646
# 14                 Karnataka               1,20,532
# 7                      Delhi               1,56,393
# 11          Himachal Pradesh                   1175
# 26                    Punjab                  14804
# 0   Andaman & Nicobar Island                    162
# 13                 Jharkhand                  16811
# 32          UT of DNH and DD                    183
# 2          Arunachal Pradesh                     20
# 6               Chhattisgarh                  20966
# 28                    Sikkim                     21
# 22                   Mizoram                     21
# 25                Puducherry                   2149
# 24                    Odisha                  23371
# 16                    Ladakh                     26
# 5                 Chandigarh                   2812
# 12         Jammu and Kashmir                   2941
# 34             Uttar Pradesh               3,37,180
# 15                    Kerala                  30775
# 33               Uttarakhand                  31008
# 10                   Haryana                  37035
# 8                        Goa                   3870
# 9                    Gujarat                  45272
# 35               West Bengal                  48767
# 21                 Meghalaya                     49
# 23                  Nagaland                     58
# 20                   Manipur                    586
# 3                      Assam                  64766
# 27                 Rajasthan                  81338
# 29                Tamil Nadu                  82051
# 4                      Bihar                  83335
# 31                   Tripura                   9262
#
#    Total Non-Electric Vehicle        Total
# 19                3,10,58,990  3,11,75,636
# 14                2,68,70,303  2,69,90,835
# 7                   76,85,600    78,41,993
# 11                  19,64,754    19,65,929
# 26                1,24,63,019  1,24,77,823
# 0                    1,46,945     1,47,107
# 13                  64,86,937    65,03,748
# 32                   3,07,671     3,07,854
# 2                    2,52,965     2,52,985
# 6                   68,36,200    68,57,166
# 28                      97189        97210
# 22                   3,15,626     3,15,647
# 25                  12,13,735    12,15,884
# 24                  98,45,073    98,68,444
# 16                      38302        38328
# 5                    7,46,881     7,49,693
# 12                  18,69,962    18,72,903
# 34                4,00,92,490  4,04,29,670
# 15                1,57,74,078  1,58,04,853
# 33                  33,12,041    33,43,049
# 10                1,07,78,270  1,08,15,305
# 8                   10,71,570    10,75,440
# 9                 2,06,05,484  2,06,50,756
# 35                1,41,34,171  1,41,82,938
# 21                   4,59,001     4,59,050
# 23                   3,39,129     3,39,187
# 20                   4,99,324     4,99,910
# 3                   46,77,053    47,41,819
# 27                1,73,27,388  1,74,08,726
# 29                2,98,42,376  2,99,24,427
# 4                 1,04,07,078  1,04,90,413
# 31                   6,50,026     6,59,288

# %%
state_data.describe(exclude=None)
# Out:
#          Sr. No.
# count  36.000000
# mean   18.500000
# std    10.535654
# min     1.000000
# 25%     9.750000
# 50%    18.500000
# 75%    27.250000
# max    36.000000

# %%
state_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Sr. No.                     36 non-null     int64
#  1   State Name                  36 non-null     object
#  2   Total Electric Vehicle      32 non-null     object
#  3   Total Non-Electric Vehicle  32 non-null     object
#  4   Total                       32 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB

# %%
EV_India
# Out:
#     Sr. No.                State Name Total Electric Vehicle  \
# 0         1  Andaman & Nicobar Island                    162
# 1         2             Andra Pradesh                    NaN
# 2         3         Arunachal Pradesh                     20
# 3         4                     Assam                  64766
# 4         5                     Bihar                  83335
# 5         6                Chandigarh                   2812
# 6         7              Chhattisgarh                  20966
# 7         8                     Delhi               1,56,393
# 8         9                       Goa                   3870
# 9        10                   Gujarat                  45272
# 10       11                   Haryana                  37035
# 11       12          Himachal Pradesh                   1175
# 12       13         Jammu and Kashmir                   2941
# 13       14                 Jharkhand                  16811
# 14       15                 Karnataka               1,20,532
# 15       16                    Kerala                  30775
# 16       17                    Ladakh                     26
# 17       18               Lakshadweep                    NaN
# 18       19            Madhya Pradesh                    NaN
# 19       20               Maharashtra               1,16,646
# 20       21                   Manipur                    586
# 21       22                 Meghalaya                     49
# 22       23                   Mizoram                     21
# 23       24                  Nagaland                     58
# 24       25                    Odisha                  23371
# 25       26                Puducherry                   2149
# 26       27                    Punjab                  14804
# 27       28                 Rajasthan                  81338
# 28       29                    Sikkim                     21
# 29       30                Tamil Nadu                  82051
# 30       31                 Telangana                    NaN
# 31       32                   Tripura                   9262
# 32       33          UT of DNH and DD                    183
# 33       34               Uttarakhand                  31008
# 34       35             Uttar Pradesh               3,37,180
# 35       36               West Bengal                  48767
#
#    Total Non-Electric Vehicle        Total
# 0                    1,46,945     1,47,107
# 1                         NaN          NaN
# 2                    2,52,965     2,52,985
# 3                   46,77,053    47,41,819
# 4                 1,04,07,078  1,04,90,413
# 5                    7,46,881     7,49,693
# 6                   68,36,200    68,57,166
# 7                   76,85,600    78,41,993
# 8                   10,71,570    10,75,440
# 9                 2,06,05,484  2,06,50,756
# 10                1,07,78,270  1,08,15,305
# 11                  19,64,754    19,65,929
# 12                  18,69,962    18,72,903
# 13                  64,86,937    65,03,748
# 14                2,68,70,303  2,69,90,835
# 15                1,57,74,078  1,58,04,853
# 16                      38302        38328
# 17                        NaN          NaN
# 18                        NaN          NaN
# 19                3,10,58,990  3,11,75,636
# 20                   4,99,324     4,99,910
# 21                   4,59,001     4,59,050
# 22                   3,15,626     3,15,647
# 23                   3,39,129     3,39,187
# 24                  98,45,073    98,68,444
# 25                  12,13,735    12,15,884
# 26                1,24,63,019  1,24,77,823
# 27                1,73,27,388  1,74,08,726
# 28                      97189        97210
# 29                2,98,42,376  2,99,24,427
# 30                        NaN          NaN
# 31                   6,50,026     6,59,288
# 32                   3,07,671     3,07,854
# 33                  33,12,041    33,43,049
# 34                4,00,92,490  4,04,29,670
# 35                1,41,34,171  1,41,82,938

# %%
EV_India
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    Transmission VehicleType         PriceRange   Capacity BootSpace  \
# 0     Automatic    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L
# 1     Automatic    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L
# 2     Automatic    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L
# 3     Automatic    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L
# 4     Automatic    Electric  ₹ 23.79 - 23.98 L  5 Seater         na
# 5     Automatic    Electric   ₹ 1.06 - 1.12 Cr  5 Seater      656 L
# 6     Automatic    Electric           ₹ 1.8 Cr  5 Seater      405 L
# 7     Automatic    Electric          ₹ 29.15 L  5 Seater      580 L
# 8     Automatic    Electric             ₹ 1 Cr  5 Seater         na
# 9     Automatic    Electric          ₹ 1.16 Cr  5 Seater         na
# 10    Automatic    Electric           ₹ 1.5 Cr  4 Seater         na
# 11    Automatic    Electric   ₹ 1.01 - 1.19 Cr  5 Seater      660 L
#
#              BaseModel             TopModel
# 0                  XM     Dark XZ Plus LUX
# 1                  XE    XZ Plus Dual Tone
# 2      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW
# 3              Excite            Exclusive
# 4   Premium Dual Tone                  HSE
# 5                   S         Sportback 55
# 6             Quattro                    na
# 7                 STD                    na
# 8                   na                   na
# 9                   na                   na
# 10                  na                   na
# 11                  na                   na

# %%
def Preprocess1(df,old_col):
#     old_col=old_col[0]
    df[old_col]=df[old_col].replace("na","0 L")
    bootspace=df[old_col].str.split("L",n=1,expand=True)
    df[old_col+"_new"]=bootspace[0]
    df[old_col+"_new"]=df[old_col+"_new"].astype(int)
    df[old_col+"_new"].mean()
    df[old_col+"_new"]=df[old_col+"_new"].replace(0,df["BootSpace_new"].mean())
    df=pd.DataFrame(df)
    return df

# %%
df=Preprocess1(EV_India,"BootSpace")

# %%
df['PriceRange']=df['PriceRange'].replace(['₹ 1.8 Cr','₹ 1.16 Cr','₹ 1.06 - 1.12 Cr','₹ 1 Cr','₹ 1.5 Cr','₹ 1.01 - 1.19 Cr'],['₹ 180 L','₹ 116 L','₹ 106 - 112 L','₹ 100 L','₹ 150 L','₹ 101 - 119 L'])
df
# Out:
#                       Car                  Style               Range  \
# 0           Tata Nexon EV            Compact SUV  312 Km/Full Charge
# 1           Tata Tigor EV       Subcompact Sedan  306 Km/Full Charge
# 2       Tata Nexon EV Max            Compact SUV  437 Km/Full Charge
# 3                MG ZS EV            Compact SUV  419 Km/Full Charge
# 4   Hyundai Kona Electric            Compact SUV  452 Km/Full Charge
# 5           Jaguar I-Pace  Premium Midsize Sedan  470 Km/Full Charge
# 6          Audi E-Tron GT          Premium Coupe  388 Km/Full Charge
# 7                  BYD E6         Subcompact MPV  415 Km/Full Charge
# 8       Mercedes-Benz EQC            Compact SUV  471 Km/Full Charge
# 9                  BMW iX   Premium Fullsize SUV  425 Km/Full Charge
# 10         Porsche Taycan   Premium Sports Sedan                  na
# 11            Audi E-Tron            Compact SUV  400 Km/Full Charge
#
#    Transmission VehicleType         PriceRange   Capacity BootSpace  \
# 0     Automatic    Electric   ₹ 13.99 - 17.4 L  5 Seater      350 L
# 1     Automatic    Electric  ₹ 12.49 - 13.64 L  5 Seater      316 L
# 2     Automatic    Electric  ₹ 17.74 - 19.24 L  5 Seater      350 L
# 3     Automatic    Electric  ₹ 21.99 - 25.88 L  5 Seater      448 L
# 4     Automatic    Electric  ₹ 23.79 - 23.98 L  5 Seater        0 L
# 5     Automatic    Electric      ₹ 106 - 112 L  5 Seater      656 L
# 6     Automatic    Electric            ₹ 180 L  5 Seater      405 L
# 7     Automatic    Electric          ₹ 29.15 L  5 Seater      580 L
# 8     Automatic    Electric            ₹ 100 L  5 Seater        0 L
# 9     Automatic    Electric            ₹ 116 L  5 Seater        0 L
# 10    Automatic    Electric            ₹ 150 L  4 Seater        0 L
# 11    Automatic    Electric      ₹ 101 - 119 L  5 Seater      660 L
#
#              BaseModel             TopModel  BootSpace_new
# 0                  XM     Dark XZ Plus LUX          350.00
# 1                  XE    XZ Plus Dual Tone          316.00
# 2      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW          350.00
# 3              Excite            Exclusive          448.00
# 4   Premium Dual Tone                  HSE          313.75
# 5                   S         Sportback 55          656.00
# 6             Quattro                    na         405.00
# 7                 STD                    na         580.00
# 8                   na                   na         313.75
# 9                   na                   na         313.75
# 10                  na                   na         313.75
# 11                  na                   na         660.00

# %%
price=df['PriceRange'].str.split('₹',n=1,expand=True)
price=price[1].str.split('-',n=1,expand=True)
st_price,fi_price=price[0],price[1]
st_price=st_price.str.split('L',n=1,expand=True)
df['StartingPrice(in Lakh)']=st_price[0].str.split('L',n=1,expand=True)
fi_price=fi_price.str.split('L',n=1,expand=True)
df['FinalPrice(in Lakh)']=fi_price[0].str.split('L',n=1,expand=True)
df['StartingPrice(in Lakh)']=df['StartingPrice(in Lakh)'].astype(float)
df['FinalPrice(in Lakh)']=df['FinalPrice(in Lakh)'].astype(float)

# %%
df
# Out:
#                       Car                  Style  Range(per Km) Transmission  \
# 0           Tata Nexon EV            Compact SUV            312    Automatic
# 1           Tata Tigor EV       Subcompact Sedan            306    Automatic
# 2       Tata Nexon EV Max            Compact SUV            437    Automatic
# 3                MG ZS EV            Compact SUV            419    Automatic
# 4   Hyundai Kona Electric            Compact SUV            452    Automatic
# 5           Jaguar I-Pace  Premium Midsize Sedan            470    Automatic
# 6          Audi E-Tron GT          Premium Coupe            388    Automatic
# 7                  BYD E6         Subcompact MPV            415    Automatic
# 8       Mercedes-Benz EQC            Compact SUV            471    Automatic
# 9                  BMW iX   Premium Fullsize SUV            425    Automatic
# 10         Porsche Taycan   Premium Sports Sedan              0    Automatic
# 11            Audi E-Tron            Compact SUV            400    Automatic
#
#    VehicleType   Capacity           BaseModel             TopModel  \
# 0     Electric  5 Seater                  XM     Dark XZ Plus LUX
# 1     Electric  5 Seater                  XE    XZ Plus Dual Tone
# 2     Electric  5 Seater      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW
# 3     Electric  5 Seater              Excite            Exclusive
# 4     Electric  5 Seater   Premium Dual Tone                  HSE
# 5     Electric  5 Seater                   S         Sportback 55
# 6     Electric  5 Seater             Quattro                    na
# 7     Electric  5 Seater                 STD                    na
# 8     Electric  5 Seater                   na                   na
# 9     Electric  5 Seater                   na                   na
# 10    Electric  4 Seater                   na                   na
# 11    Electric  5 Seater                   na                   na
#
#     BootSpace_new  StartingPrice(in Lakh)  FinalPrice(in Lakh)
# 0          350.00                   13.99                17.40
# 1          316.00                   12.49                13.64
# 2          350.00                   17.74                19.24
# 3          448.00                   21.99                25.88
# 4          313.75                   23.79                23.98
# 5          656.00                  106.00               112.00
# 6          405.00                  180.00                 0.00
# 7          580.00                   29.15                 0.00
# 8          313.75                  100.00                 0.00
# 9          313.75                  116.00                 0.00
# 10         313.75                  150.00                 0.00
# 11         660.00                  101.00               119.00

# %%
df['Range']=df['Range'].replace('na','0 Km/Full Charge')
df[['Range','Unit']]=df['Range'].str.split(' ',n=1,expand=True)
df=df.drop(['Unit'],axis=1)
# df['Range']=df['Range'].replace("na",0)
df['Range']=df['Range'].astype(int)

# %%
df
# Out:
#                       Car                  Style  Range(per Km) Transmission  \
# 0           Tata Nexon EV            Compact SUV            312    Automatic
# 1           Tata Tigor EV       Subcompact Sedan            306    Automatic
# 2       Tata Nexon EV Max            Compact SUV            437    Automatic
# 3                MG ZS EV            Compact SUV            419    Automatic
# 4   Hyundai Kona Electric            Compact SUV            452    Automatic
# 5           Jaguar I-Pace  Premium Midsize Sedan            470    Automatic
# 6          Audi E-Tron GT          Premium Coupe            388    Automatic
# 7                  BYD E6         Subcompact MPV            415    Automatic
# 8       Mercedes-Benz EQC            Compact SUV            471    Automatic
# 9                  BMW iX   Premium Fullsize SUV            425    Automatic
# 10         Porsche Taycan   Premium Sports Sedan              0    Automatic
# 11            Audi E-Tron            Compact SUV            400    Automatic
#
#    VehicleType   Capacity           BaseModel             TopModel  \
# 0     Electric  5 Seater                  XM     Dark XZ Plus LUX
# 1     Electric  5 Seater                  XE    XZ Plus Dual Tone
# 2     Electric  5 Seater      XZ Plus 3.3 kW   XZ Plus Lux 7.2 kW
# 3     Electric  5 Seater              Excite            Exclusive
# 4     Electric  5 Seater   Premium Dual Tone                  HSE
# 5     Electric  5 Seater                   S         Sportback 55
# 6     Electric  5 Seater             Quattro                    na
# 7     Electric  5 Seater                 STD                    na
# 8     Electric  5 Seater                   na                   na
# 9     Electric  5 Seater                   na                   na
# 10    Electric  4 Seater                   na                   na
# 11    Electric  5 Seater                   na                   na
#
#     BootSpace_new  StartingPrice(in Lakh)  FinalPrice(in Lakh)
# 0          350.00                   13.99                17.40
# 1          316.00                   12.49                13.64
# 2          350.00                   17.74                19.24
# 3          448.00                   21.99                25.88
# 4          313.75                   23.79                23.98
# 5          656.00                  106.00               112.00
# 6          405.00                  180.00                 0.00
# 7          580.00                   29.15                 0.00
# 8          313.75                  100.00                 0.00
# 9          313.75                  116.00                 0.00
# 10         313.75                  150.00                 0.00
# 11         660.00                  101.00               119.00

# %%
df['Car'].unique()
# Out:
# array(['Tata Nexon EV', 'Tata Tigor EV', 'Tata Nexon EV Max', 'MG ZS EV',
#        'Hyundai Kona Electric', 'Jaguar I-Pace', 'Audi E-Tron GT',
#        'BYD E6', 'Mercedes-Benz EQC', 'BMW iX', 'Porsche Taycan',
#        'Audi E-Tron'], dtype=object)

# %%
# plotting correlation heatmap
dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)

# %%
df.columns=['Car', 'Style', 'Range(per Km)', 'Transmission', 'VehicleType', 'PriceRange','Capacity', 'BootSpace', 'BaseModel', 'TopModel', 'BootSpace_new','StartingPrice(in Lakh)', 'FinalPrice(in Lakh)']

# %%
df.drop(['PriceRange','BootSpace'],axis=1,inplace=True)

# %%
df['FinalPrice(in Lakh)']=df['FinalPrice(in Lakh)'].fillna(0.0)

# %%
style=df['Style'].value_counts()
style
# Out:
# Compact SUV              6
# Subcompact Sedan         1
# Premium Midsize Sedan    1
# Premium Coupe            1
# Subcompact MPV           1
# Premium Fullsize SUV     1
# Premium Sports Sedan     1
# Name: Style, dtype: int64

# %%
def count_plot(col,df,con,title):
    plt.figure(figsize=(10,6))
    sb.countplot(y='Style',data=df,order=con,palette='coolwarm_r')
    plt.title(title,{'fontweight':'bold','fontsize':'larger'})
    plt.show()
con=style.index
count_plot('Style',df,con,"Style Distribution")

# %%
range_style=df.groupby('Style')['Range(per Km)'].mean()

# %%
plt.figure(figsize=(18,8))
# sb.barplot(x=range_style.index,y=range_style.values)
# plt.barh(y=range_style.index,width=range_style.values,color='#CD5C5C')
plt.bar(x=range_style.index,height=range_style.values,color='#CD5C5C')
plt.title('Range(per Km) based on style of the vehicles',{'fontweight':'bold','fontsize':'larger'})
plt.xlabel("Style",{'fontweight':'bold','fontsize':'larger'})
plt.ylabel("Range(per Km)",{'fontweight':'bold','fontsize':'larger'})
# Out:
# Text(0, 0.5, 'Range(per Km)')

# %%
df.groupby(['Style','Car'])['StartingPrice(in Lakh)'].max()
# Out:
# Style                  Car
# Compact SUV            Audi E-Tron              101.00
#                        Hyundai Kona Electric     23.79
#                        MG ZS EV                  21.99
#                        Mercedes-Benz EQC        100.00
#                        Tata Nexon EV             13.99
#                        Tata Nexon EV Max         17.74
# Premium Coupe          Audi E-Tron GT           180.00
# Premium Fullsize SUV   BMW iX                   116.00
# Premium Midsize Sedan  Jaguar I-Pace            106.00
# Premium Sports Sedan   Porsche Taycan           150.00
# Subcompact MPV         BYD E6                    29.15
# Subcompact Sedan       Tata Tigor EV             12.49
# Name: StartingPrice(in Lakh), dtype: float64

# %%
start_price=df.groupby('Style')['StartingPrice(in Lakh)'].mean()

# %%
plt.figure(figsize=(18,8))
# sb.barplot(x=range_style.index,y=range_style.values)
# plt.barh(y=range_style.index,width=range_style.values,color='#CD5C5C')
plt.bar(x=start_price.index,height=start_price.values,color='#EE8912')
plt.title('Starting Price(in Lakh) based on style',{'fontweight':'bold','fontsize':'larger'})
plt.xlabel("Style",{'fontweight':'bold','fontsize':'larger'})
plt.ylabel("Starting Price(in Lakh)",{'fontweight':'bold','fontsize':'larger'})
# Out:
# Text(0, 0.5, 'Starting Price(in Lakh)')

# %%
India_data
# Out:
#                                   State Name  Two Wheeler  Three Wheeler  \
# 0                 Andaman and Nicobar Island            1           30.0
# 1                          Arunachal Pradesh           14            NaN
# 2                                      Assam          721        47041.0
# 3                                      Bihar         5003        59079.0
# 4                                 Chandigarh          298         1410.0
# 5                               Chhattisgarh         6424         5341.0
# 6                                      Delhi        14730       112831.0
# 7                                        Goa         1314           28.0
# 8                                    Gujarat        13662         1869.0
# 9                                    Haryana         7777        18595.0
# 10                          Himachal Pradesh          368          167.0
# 11                         Jammu and Kashmir         1417           43.0
# 12                                 Jharkhand         2961         8986.0
# 13                                 Karnataka        56737        16478.0
# 14                                    Kerala        10299         2115.0
# 15                                    Ladakh           12            NaN
# 16                               Maharashtra        51149         6155.0
# 17                                   Manipur           86          443.0
# 18                                 Meghalaya           16            6.0
# 19                                   Mizoram            9            1.0
# 20                                  Nagaland           44            NaN
# 21                                    Odisha        10329         1808.0
# 22                                Puducherry         1429           32.0
# 23                                    Punjab         6408         2878.0
# 24                                 Rajasthan        23446        29631.0
# 25                                    Sikkim            1            NaN
# 26                                Tamil Nadu        44302         4470.0
# 27                                   Tripura           67         7510.0
# 28  Dadra and Nagar Haveli and Daman and Diu           69           36.0
# 29                             Uttar Pradesh        18295       257159.0
# 30                               Uttarakhand         2614        22096.0
# 31                               West Bengal         2540        40948.0
#
#     Four Wheeler  Goods Vehicles  Public Service Vehicle  \
# 0             81             NaN                    40.0
# 1              5             NaN                     NaN
# 2            161             7.0                    15.0
# 3            114            11.0                    26.0
# 4            182             NaN                    40.0
# 5            117          1077.0                     1.0
# 6           3051            49.0                    39.0
# 7            289            13.0                    36.0
# 8           1309            28.0                   278.0
# 9            186           122.0                     8.0
# 10            37             7.0                    86.0
# 11            10             6.0                    43.0
# 12           139            24.0                     4.0
# 13          7212           153.0                    44.0
# 14          2524            43.0                    23.0
# 15          5484             NaN                     NaN
# 16             2            30.0                   851.0
# 17             9             1.0                     NaN
# 18             3             3.0                     NaN
# 19             4             2.0                     1.0
# 20           121             3.0                     NaN
# 21            75            21.0                     NaN
# 22           124             9.0                    20.0
# 23           798            35.0                     2.0
# 24            12            25.0                     1.0
# 25          2414             1.0                     NaN
# 26            13          1281.0                    37.0
# 27            14             1.0                     NaN
# 28           153             2.0                    10.0
# 29           368            53.0                   327.0
# 30           709             1.0                    10.0
# 31           615            28.0                    97.0
#
#     Special Category Vehicles  Ambulance/Hearses  \
# 0                         NaN                NaN
# 1                         NaN                NaN
# 2                         NaN                NaN
# 3                         NaN                NaN
# 4                         NaN                NaN
# 5                         NaN                NaN
# 6                         NaN                NaN
# 7                         2.0                NaN
# 8                       344.0                NaN
# 9                         2.0                NaN
# 10                        NaN                NaN
# 11                        NaN                NaN
# 12                        NaN                NaN
# 13                        1.0                1.0
# 14                        NaN                1.0
# 15                        NaN                NaN
# 16                       26.0                1.0
# 17                        NaN                NaN
# 18                        NaN                NaN
# 19                        NaN                NaN
# 20                        1.0                NaN
# 21                       25.0                NaN
# 22                        NaN                NaN
# 23                        NaN                NaN
# 24                        NaN                1.0
# 25                        NaN                NaN
# 26                        NaN                NaN
# 27                        NaN                NaN
# 28                        7.0                NaN
# 29                        2.0                NaN
# 30                        NaN                NaN
# 31                        NaN                2.0
#
#     Construction Equipment Vehicle   Other
# 0                              NaN     7.0
# 1                              NaN     1.0
# 2                              NaN     2.0
# 3                              NaN     8.0
# 4                              NaN     1.0
# 5                            368.0   100.0
# 6                              NaN  1602.0
# 7                              NaN     4.0
# 8                             26.0    77.0
# 9                              NaN    90.0
# 10                             NaN    46.0
# 11                             NaN     8.0
# 12                             NaN    57.0
# 13                             NaN  1420.0
# 14                             NaN    17.0
# 15                             NaN     NaN
# 16                             NaN   601.0
# 17                             NaN     1.0
# 18                             NaN     NaN
# 19                             NaN     3.0
# 20                             1.0     1.0
# 21                             1.0    23.0
# 22                             NaN     NaN
# 23                             NaN    21.0
# 24                             1.0    24.0
# 25                             NaN     9.0
# 26                             NaN   193.0
# 27                             NaN     1.0
# 28                             NaN     NaN
# 29                             NaN    13.0
# 30                             NaN    21.0
# 31                             NaN    61.0
